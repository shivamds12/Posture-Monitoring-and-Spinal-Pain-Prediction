# %%
import serial
import time

# === Configuration ===
SERIAL_PORT = "COM5"   # Change this to your Arduino COM port
BAUD_RATE = 9600

# === Open the serial port ===
try:
    ser = serial.Serial(SERIAL_PORT, BAUD_RATE, timeout=1)
except Exception as e:
    print(f"Error opening serial port: {e}")
    exit()

# Give Arduino time to initialize
time.sleep(2)

print("Calculating change in degrees every second:")

while True:
    start_time = time.time()
    # Initialize integrated angles for each axis (in degrees)
    integrated_x = 0.0
    integrated_y = 0.0
    integrated_z = 0.0
    
    # For dt calculation between successive readings
    last_time = time.time()
    
    # Collect data for a full second
    while time.time() - start_time < 1:
        if ser.in_waiting > 0:
            try:
                line = ser.readline().decode('utf-8').strip()
                # Expected format: "X: <value> | Y: <value> | Z: <value>"
                if line.startswith("X:"):
                    parts = line.split(" | ")
                    x_val = float(parts[0].split(":")[1].strip())
                    y_val = float(parts[1].split(":")[1].strip())
                    z_val = float(parts[2].split(":")[1].strip())
                    
                    current_time = time.time()
                    dt = current_time - last_time
                    last_time = current_time
                    
                    # Integrate angular velocity (deg/s) over time (dt) to compute change in degrees
                    integrated_x += x_val * dt
                    integrated_y += y_val * dt
                    integrated_z += z_val * dt
                    
            except Exception as e:
                print("Error reading line:", e)
    
    # Print the total angle change computed over the last 1 second
    print(f"Angle change in 1 sec -> X: {integrated_x:.2f}°, Y: {integrated_y:.2f}°, Z: {integrated_z:.2f}°")
# Out:
# Calculating change in degrees every second:
# Angle change in 1 sec -> X: -3.35°, Y: 0.83°, Z: 1.64°
# Angle change in 1 sec -> X: -2.61°, Y: 1.75°, Z: 1.65°
# Angle change in 1 sec -> X: -1.21°, Y: 0.43°, Z: 1.46°
# Angle change in 1 sec -> X: -1.98°, Y: -0.63°, Z: 1.77°
# Angle change in 1 sec -> X: -2.95°, Y: 0.87°, Z: 1.20°
# Angle change in 1 sec -> X: -2.51°, Y: 17.20°, Z: 4.68°
# Angle change in 1 sec -> X: -6.05°, Y: 19.14°, Z: 5.29°
# Angle change in 1 sec -> X: 4.17°, Y: -6.40°, Z: 3.91°
# Angle change in 1 sec -> X: 8.64°, Y: -23.46°, Z: 9.71°
# Angle change in 1 sec -> X: -3.03°, Y: -9.31°, Z: 0.37°
# Angle change in 1 sec -> X: -3.48°, Y: -1.28°, Z: 0.03°
# Angle change in 1 sec -> X: -2.28°, Y: -17.17°, Z: 2.19°
# Angle change in 1 sec -> X: -2.18°, Y: -11.48°, Z: 2.66°
# Angle change in 1 sec -> X: -2.34°, Y: -4.83°, Z: 1.50°
# Angle change in 1 sec -> X: -3.72°, Y: -2.88°, Z: 0.27°
# Angle change in 1 sec -> X: -1.83°, Y: -5.69°, Z: 2.30°
# Angle change in 1 sec -> X: -1.55°, Y: -0.92°, Z: 1.41°
# Angle change in 1 sec -> X: -3.23°, Y: 0.93°, Z: 1.18°
# Angle change in 1 sec -> X: -2.16°, Y: 0.15°, Z: 0.85°
# Angle change in 1 sec -> X: -3.47°, Y: 10.38°, Z: 1.99°
# Angle change in 1 sec -> X: 0.98°, Y: 32.17°, Z: 0.82°
# Angle change in 1 sec -> X: -0.17°, Y: 4.14°, Z: 0.22°
# Angle change in 1 sec -> X: -3.23°, Y: 1.10°, Z: 1.56°
# Angle change in 1 sec -> X: -5.12°, Y: -0.50°, Z: 2.70°
# Angle change in 1 sec -> X: -0.95°, Y: 1.23°, Z: 2.33°
# Angle change in 1 sec -> X: -0.45°, Y: -11.31°, Z: 20.13°
# Angle change in 1 sec -> X: -8.09°, Y: 12.80°, Z: 35.73°
# Angle change in 1 sec -> X: 2.56°, Y: -0.19°, Z: 12.80°
# Angle change in 1 sec -> X: -2.64°, Y: 5.51°, Z: -1.18°
# Angle change in 1 sec -> X: 11.67°, Y: -9.13°, Z: -43.33°
# Angle change in 1 sec -> X: -14.63°, Y: 1.80°, Z: -12.86°
# Angle change in 1 sec -> X: -3.43°, Y: 4.05°, Z: 1.14°
# Angle change in 1 sec -> X: -4.28°, Y: -3.36°, Z: 2.47°
# Angle change in 1 sec -> X: -5.72°, Y: -29.84°, Z: 1.98°
# Angle change in 1 sec -> X: -1.54°, Y: -1.09°, Z: -1.36°
# Angle change in 1 sec -> X: 3.11°, Y: 47.51°, Z: 1.97°
# Angle change in 1 sec -> X: -1.87°, Y: -0.90°, Z: 1.87°
# Angle change in 1 sec -> X: -4.13°, Y: 1.24°, Z: 0.45°
# Angle change in 1 sec -> X: -2.12°, Y: 6.78°, Z: 0.33°
# Angle change in 1 sec -> X: -2.24°, Y: 0.22°, Z: 1.62°
# Angle change in 1 sec -> X: -3.47°, Y: 1.21°, Z: 1.16°
# Angle change in 1 sec -> X: -3.15°, Y: 1.28°, Z: 1.57°
# Angle change in 1 sec -> X: -3.04°, Y: -2.40°, Z: 1.33°
# Angle change in 1 sec -> X: -2.93°, Y: 0.63°, Z: 1.34°
# Angle change in 1 sec -> X: -3.21°, Y: 1.08°, Z: 0.55°
# Angle change in 1 sec -> X: -3.93°, Y: -1.24°, Z: 1.45°
# Angle change in 1 sec -> X: -3.58°, Y: 0.75°, Z: 1.28°
# Angle change in 1 sec -> X: -2.53°, Y: 0.99°, Z: 1.02°
# Angle change in 1 sec -> X: -2.21°, Y: 1.10°, Z: 1.71°
# Angle change in 1 sec -> X: -2.11°, Y: -0.35°, Z: 1.70°
# Angle change in 1 sec -> X: -3.17°, Y: 3.17°, Z: 0.87°
# Angle change in 1 sec -> X: -1.95°, Y: 1.26°, Z: 1.85°
# Angle change in 1 sec -> X: -3.13°, Y: 0.37°, Z: 2.03°
# Angle change in 1 sec -> X: -2.90°, Y: 0.63°, Z: 1.34°
# Angle change in 1 sec -> X: -3.56°, Y: 1.30°, Z: 1.53°
# Angle change in 1 sec -> X: -2.15°, Y: 1.14°, Z: 1.22°
# Angle change in 1 sec -> X: -2.87°, Y: 1.10°, Z: 1.41°
# Angle change in 1 sec -> X: -2.78°, Y: 2.92°, Z: 1.51°
# Angle change in 1 sec -> X: -1.87°, Y: 1.01°, Z: 1.75°
# Angle change in 1 sec -> X: -1.59°, Y: 0.92°, Z: 1.89°
# Angle change in 1 sec -> X: -3.56°, Y: 1.79°, Z: 1.24°
# Angle change in 1 sec -> X: -2.91°, Y: -0.81°, Z: 1.90°
# Angle change in 1 sec -> X: -2.49°, Y: -0.58°, Z: 1.44°
# Angle change in 1 sec -> X: -1.77°, Y: 0.19°, Z: 1.64°
# Angle change in 1 sec -> X: -2.40°, Y: 1.69°, Z: 1.29°
# Angle change in 1 sec -> X: -2.50°, Y: 0.70°, Z: 1.74°
# Angle change in 1 sec -> X: -2.37°, Y: 1.89°, Z: 0.93°
# Angle change in 1 sec -> X: -3.39°, Y: 0.63°, Z: 1.49°
# Angle change in 1 sec -> X: -1.31°, Y: 2.21°, Z: 1.45°
# Angle change in 1 sec -> X: -2.81°, Y: 2.41°, Z: 1.11°
# Angle change in 1 sec -> X: -1.80°, Y: 3.55°, Z: -0.05°
# Angle change in 1 sec -> X: -3.75°, Y: -1.32°, Z: 1.89°
# Angle change in 1 sec -> X: -2.23°, Y: -0.17°, Z: 1.90°
# Angle change in 1 sec -> X: -4.18°, Y: 1.09°, Z: 1.06°
# Angle change in 1 sec -> X: -3.60°, Y: 0.80°, Z: 1.57°
# Angle change in 1 sec -> X: -1.98°, Y: 3.21°, Z: 1.33°
# Angle change in 1 sec -> X: -2.80°, Y: 1.48°, Z: 1.42°
# Angle change in 1 sec -> X: -2.39°, Y: 1.68°, Z: 1.51°
# Angle change in 1 sec -> X: -2.29°, Y: 1.47°, Z: 1.75°
# Angle change in 1 sec -> X: -3.49°, Y: 1.86°, Z: 0.98°
# Angle change in 1 sec -> X: -1.96°, Y: 1.46°, Z: 1.39°
# Angle change in 1 sec -> X: -2.62°, Y: 0.88°, Z: 1.40°
# Angle change in 1 sec -> X: -4.79°, Y: 33.52°, Z: 3.30°
# Angle change in 1 sec -> X: -1.43°, Y: 7.58°, Z: 2.36°
# Angle change in 1 sec -> X: -2.11°, Y: -22.05°, Z: -0.15°
# Angle change in 1 sec -> X: -3.10°, Y: -20.39°, Z: 2.31°
# Angle change in 1 sec -> X: -2.20°, Y: 4.28°, Z: 1.43°
# Angle change in 1 sec -> X: -1.37°, Y: 5.47°, Z: 1.39°
# Angle change in 1 sec -> X: -3.54°, Y: 1.70°, Z: 1.10°
# Angle change in 1 sec -> X: -2.98°, Y: 2.13°, Z: 0.95°
# Angle change in 1 sec -> X: -2.46°, Y: 1.55°, Z: 1.39°
# Angle change in 1 sec -> X: -2.02°, Y: 0.66°, Z: 1.28°
# Angle change in 1 sec -> X: -2.92°, Y: 0.59°, Z: 1.51°
# Angle change in 1 sec -> X: -3.30°, Y: -0.22°, Z: 2.16°
# Angle change in 1 sec -> X: -1.91°, Y: 1.51°, Z: 1.58°
# Angle change in 1 sec -> X: -2.36°, Y: 0.48°, Z: 1.60°
# Angle change in 1 sec -> X: -2.18°, Y: -3.22°, Z: 2.89°
# Angle change in 1 sec -> X: -3.98°, Y: -0.29°, Z: 1.50°
# Angle change in 1 sec -> X: -2.66°, Y: 3.99°, Z: 0.52°
# Angle change in 1 sec -> X: -3.07°, Y: 3.91°, Z: 0.43°
# Angle change in 1 sec -> X: -1.08°, Y: 9.67°, Z: 0.89°
# Angle change in 1 sec -> X: -1.60°, Y: 15.89°, Z: 1.65°
# Angle change in 1 sec -> X: 0.49°, Y: 1.38°, Z: 0.77°
# Angle change in 1 sec -> X: -2.99°, Y: 1.62°, Z: 1.29°
# Angle change in 1 sec -> X: -2.92°, Y: -4.09°, Z: 3.76°
# Angle change in 1 sec -> X: -7.37°, Y: -17.88°, Z: 2.29°
# Angle change in 1 sec -> X: -3.62°, Y: 1.04°, Z: -1.30°
# Angle change in 1 sec -> X: -3.27°, Y: -1.46°, Z: 2.73°
# Angle change in 1 sec -> X: -3.01°, Y: 1.86°, Z: 1.01°
# Angle change in 1 sec -> X: -0.29°, Y: -15.82°, Z: 0.37°
# Angle change in 1 sec -> X: -5.40°, Y: -25.93°, Z: 0.24°
# Angle change in 1 sec -> X: -2.69°, Y: 1.55°, Z: 1.81°
# Angle change in 1 sec -> X: -2.86°, Y: 0.08°, Z: 1.73°
